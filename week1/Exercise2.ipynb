# %% [markdown]
# # Intro to Data Science week 1, exercise 2
#
# N.B! 2.1 and 2.2 don't produce inputs/outputs
# ...so let's just initialize helpers.

# %%
import pandas as pd

def updateCol(df, colName, fn):
    """
    Takes DataFrame, column name and function. Applies function to column and returns a new copy of updated DataFrame.
    """
    
    newval = df[colName].apply(fn)
    kwargs = {colName: newval}
    return df.assign(**kwargs)

# %% [markdown]
# ### Exercise 2.3:
# a)
# First we need to make the file valid JSON and then read it

# %%
def arrayify_set_of_json(sourcefile, destfile):
    source = open(sourcefile, 'r')
    dest = open(destfile, 'w')
    line = source.readline()
    dest.write('[')
    while(line):
        dest.write(line)
        nextline = source.readline()
        if(nextline):
            dest.write(',')
            line = nextline
        else:
            line = None
    dest.write(']')
    source.close()
    dest.close()

source = 'reviews_automotive_5.json'
datafile = 'reviews_automotive_5_proper.json'

arrayify_set_of_json(source, datafile)

# %% [markdown]
# ...and then we can read it!

# %%
data = pd.read_json(datafile)
print(data)
# Out:
#              asin   helpful  overall  \
# 0      B00002243X    [4, 4]        5
# 1      B00002243X    [1, 1]        4
# 2      B00002243X    [0, 0]        5
# 3      B00002243X  [19, 19]        5
# 4      B00002243X    [0, 0]        5
# 5      B00002243X    [1, 1]        5
# 6      B00002243X    [1, 1]        5
# 7      B00002243X    [0, 0]        5
# 8      B00002243X    [0, 0]        4
# 9      B00002243X    [0, 0]        5
# 10     B00002243Z    [0, 0]        4
# 11     B00002243Z  [19, 21]        5
# 12     B00002243Z    [0, 0]        5
# 13     B00002243Z  [20, 21]        4
# 14     B00002243Z    [1, 1]        4
# 15     B00002243Z    [1, 3]        4
# 16     B00008BKX5    [0, 0]        3
# 17     B00008BKX5    [3, 4]        4
# 18     B00008BKX5  [51, 51]        5
# 19     B00008BKX5    [0, 0]        5
# 20     B00008BKX5    [0, 0]        5
# 21     B00008BKX5    [0, 0]        4
# 22     B00008BKX5    [1, 1]        5
# 23     B00008RW9U    [1, 2]        5
# 24     B00008RW9U    [3, 3]        3
# 25     B00008RW9U   [3, 10]        2
# 26     B00008RW9U    [0, 0]        5
# 27     B00008RW9U    [0, 0]        5
# 28     B00008RW9U    [0, 0]        5
# 29     B00008RW9U    [0, 0]        5
# ...           ...       ...      ...
# 20443  B00I93BOZ0    [1, 1]        5
# 20444  B00I93BOZ0    [0, 0]        5
# 20445  B00I93BOZ0    [0, 0]        3
# 20446  B00I93BOZ0    [0, 0]        4
# 20447  B00I93BOZ0    [0, 0]        5
# 20448  B00I93BOZ0    [0, 0]        5
# 20449  B00I93BOZ0    [1, 1]        5
# 20450  B00JGM7Z5Q    [0, 0]        5
# 20451  B00JGM7Z5Q    [1, 1]        5
# 20452  B00JGM7Z5Q    [1, 1]        5
# 20453  B00JGM7Z5Q    [0, 0]        5
# 20454  B00JGM7Z5Q    [0, 0]        5
# 20455  B00JGM7Z5Q    [4, 8]        4
# 20456  B00JGP8I1S    [2, 2]        5
# 20457  B00JGP8I1S    [0, 0]        3
# 20458  B00JGP8I1S    [2, 2]        4
# 20459  B00JGP8I1S    [2, 2]        5
# 20460  B00JGP8I1S    [1, 1]        3
# 20461  B00JGP8I1S    [2, 2]        4
# 20462  B00JGP8I1S    [1, 1]        3
# 20463  B00KIAQ8VW    [0, 0]        5
# 20464  B00KIAQ8VW    [0, 0]        4
# 20465  B00KIAQ8VW    [0, 0]        5
# 20466  B00KIAQ8VW    [0, 0]        3
# 20467  B00KIAQ8VW    [0, 0]        2
# 20468  B00KIAQ8VW    [1, 1]        5
# 20469  B00KIAQ8VW    [0, 0]        2
# 20470  B00KIAQ8VW    [0, 0]        5
# 20471  B00KIAQ8VW    [0, 0]        5
# 20472  B00KIAQ8VW    [0, 0]        5
#
#                                               reviewText   reviewTime  \
# 0      I needed a set of jumper cables for my new car...  08 17, 2011
# 1      These long cables work fine for my truck, but ...   09 4, 2011
# 2      Can't comment much on these since they have no...  07 25, 2013
# 3      I absolutley love Amazon!!!  For the price of ...  12 21, 2010
# 4      I purchased the 12' feet long cable set and th...   07 4, 2012
# 5      These Jumper cables are heavy Duty, Yet easy t...  11 14, 2009
# 6      bought these for my k2500 suburban plenty of l...  01 10, 2012
# 7      these are good enough to get most motorized ve...  06 13, 2013
# 8      The Coleman Cable 08665 12-Feet Heavy-Duty Tru...  07 18, 2013
# 9      I have an old car, Its bound to need these som...  01 22, 2014
# 10     I seem to use jumper cables at least several t...  10 14, 2013
# 11     All other jumper cables are not real jumper ca...  10 22, 2010
# 12     I'm one of those guys who stops and helps peop...  12 27, 2013
# 13     So these aren't the best cables you can buy.  ...  12 22, 2010
# 14     It is hard to find pure copper cabled jumper c...   09 8, 2013
# 15     These are an insurance policy for my Land Rove...  01 17, 2013
# 16     This product serves its purpose. I use it for ...  11 15, 2013
# 17     Hitch extender is good for Kayak transport and...   09 6, 2010
# 18                                                        08 11, 2011
# 19     Package arrived a bit ragged but it was all th...   07 9, 2012
# 20     This was exactly what I needed for transportin...  09 25, 2012
# 21     I bought these to haul my two kayaks.  Works g...  07 16, 2012
# 22     I have owned trucks for many years and gotten ...  01 24, 2012
# 23     This is a must for anybody who wants to keep t...   06 5, 2011
# 24     this product does what it is supposed to do, b...   05 7, 2009
# 25     I would not buy this product again. It does wh...  07 21, 2009
# 26     I own the Original California Car Duster and i...   01 2, 2009
# 27     Like most car detail enthusiasts, I never like...  07 23, 2009
# 28     Takes the dust off my car without leaving any ...  05 16, 2014
# 29     Really the best car duster out there in my opi...   03 6, 2013
# ...                                                  ...          ...
# 20443  Great kit at a great price. Usually if you go ...  03 31, 2014
# 20444  Ah, this is such goofy fun, to jazz up your ca...  05 14, 2014
# 20445  Basically these led lights are a nice addition...  04 15, 2014
# 20446  We've never had a product like this before, bu...  05 14, 2014
# 20447  OK, I'm a light nut. I fabricate my own LED li...  04 20, 2014
# 20448  Nice addition to the interior of any hot teens...   04 4, 2014
# 20449  While most will probably install these inside ...  03 27, 2014
# 20450  What an awesome idea this board is. It turns y...  07 20, 2014
# 20451  The work surface is nice size, and built well....   07 8, 2014
# 20452  I have a small kitchen, so using the stove top...   07 2, 2014
# 20453  If you've ever needed a little more work space...  07 21, 2014
# 20454  Thin,light weightDurableBeautifulThis is a MUC...  07 17, 2014
# 20455  Wife 2.0 has never much cared for the kitchen ...  06 25, 2014
# 20456  I live in a very sunny climate.  At least once...   07 7, 2014
# 20457  This is an interesting product. It definitely ...  07 12, 2014
# 20458  This actually works pretty well. The yellow re...   07 6, 2014
# 20459  This is a vision visor for the car. It has two...   07 5, 2014
# 20460  I'm afraid I'm not sold on this. It does exact...  07 16, 2014
# 20461  It is a good sunshade for driving on bright su...  07 13, 2014
# 20462  I received a visor set free for review purpose...   07 3, 2014
# 20463  Keeps the bugs out of your mouth while looking...  07 15, 2013
# 20464  I use them all the time when I ride or not I h...  12 16, 2013
# 20465  i think this is a cool yet sweet looking half ...  11 19, 2013
# 20466  I honestly don't think it's worth $3, but for ...  03 15, 2014
# 20467  very thin material. not very warm at all.. bar...  02 11, 2014
# 20468  I've bought 10 of these over the past year to ...   04 8, 2014
# 20469  OK, I have to admit, the price of this item di...   02 4, 2014
# 20470  I love my skull face mask. It makes me outstan...   12 9, 2013
# 20471  This mask of course as described is half-face ...   01 3, 2013
# 20472  Good light weight for just cool nights or rain...  03 18, 2014
#
#            reviewerID                                      reviewerName  \
# 0      A3F73SC1LY51OO                                   Alan Montgomery
# 1      A20S66SKYXULG2                                          alphonse
# 2      A2I8LFSN2IS5EO                                             Chris
# 3      A3GT2EWQSO45ZG                                            DeusEx
# 4      A3ESWJPAVRPWB4                                      E. Hernandez
# 5       A1ORODEBRN64C                      James F. Magowan "Jimmy Mac"
# 6      A2R49ZN3G6FTCQ                                   John M. Harrell
# 7      A1Q65KYDKXIX8E                                        Leeland H.
# 8      A3BI8BKIHESDNQ                                  L. J. Cunningham
# 9      A1R089P5AS26UE                                              Mike
# 10     A2TQST4IPVA0EC                                              ACAR
# 11     A3MQAQT8C6D1I7                                   AverageReviewer
# 12     A1C6RZG7XQZBUZ  C. Beard "I have not gone where I intended to...
# 13     A3GT2EWQSO45ZG                                            DeusEx
# 14     A3I23XW4L5ITOG                                           Hemmi06
# 15     A30ASPRK2VP8QC                                             Robin
# 16     A1KKOA3FP2DMBW                                    Brian LaFrance
# 17     A3L1VJMHFWONCB                                CDP "Double00Buck"
# 18      A1HPC4BDRLR60                                        Delta Echo
# 19     A3IHX99Z9OK2Y9                                         Gulfcoast
# 20      AT5F1MKA8C2IZ                                         R. Gillis
# 21      A4YV49T8Y0X94                                   RobbyB "RobbyB"
# 22     A204K1OFE8OB9Y                                            Winter
# 23     A36HBGDEFPWD0U                                             Brett
# 24     A2FJKITDY5UUHJ                                  Charles M. Cline
# 25     A3LYC4BXRDE5RZ                                       Chi Car Guy
# 26      AEL6CQNQXONBX                                    Cute Chihuahua
# 27     A3APEIJOQXE142                     Daniel Attila "Daniel Attila"
# 28     A24EQC4LXYPT4E                                              Dave
# 29     A2H5KD2A9MUZEX                                           Gaazmon
# ...               ...                                               ...
# 20443  A2JMJVNTBL7K7E                               K. Lin "yesuaini99"
# 20444   ASFW4ZMNZJKDA                                           Mainiac
# 20445  A2X6J6AFLLYVXH                                    Michael Hilton
# 20446  A105S56ODHGJEK                Peace Daddy "Eclectic ReflectionZ"
# 20447  A3LGT6UZL99IW1  Richard C. Drew "Anaal Nathra/Uthe vas Bethod...
# 20448  A3MQ15651KGVLJ                                   Rick L. Parrish
# 20449   AM9APPMIE1BHZ                                      Sparky Jones
# 20450  A1F7YU6O5RU432                                    Angela Streiff
# 20451  A397CWU6DM3O5G                                             ganka
# 20452  A1M1Y5UGONAW06                                              Jody
# 20453  A3SD3E6FIS6CS9                                Marine Corps Nomad
# 20454  A376OJHLE6SU9Q                                           M. Wolf
# 20455  A25QJBK33C4O0R                               terpfan1980 "Barry"
# 20456  A19UTUEBWKIZFT                                               AKN
# 20457  A1T1YSCDW0PD25                                        A. Wiersch
# 20458  A34BZM6S9L7QI4                       Candy Cane "Is it just me?"
# 20459   AYB4ELCS5AM8P                               John B. Goode "JBG"
# 20460  A1EVV74UQYVKRY                                           K. Groh
# 20461  A1ODOGXEYECQQ8                                            Nuknuk
# 20462  A3A4ZAIBQWKOZS                                  Stephen M. Lerch
# 20463  A1RH7WA3YFDQ5H                                        Denise2012
# 20464  A1PMV0WV45OPEE                                         Dwayne C.
# 20465   ACHBPQUWQZMSL                              ernies point of veiw
# 20466  A1TEBSNK5A9XX9                                               JUL
# 20467  A212UJA6XIOTUT                                               kaz
# 20468  A1KB43BI085A48                                           Mike F.
# 20469  A3HIUWKL4D853W                                              RayH
# 20470  A1S95WASXJ02VX                               Roberto Aguilar Jr.
# 20471  A2IID0Z6EHF5KP                                            Soarer
# 20472  A3HKZTFCPIK2OE                SSG Barnes (ABN) "James C. Barnes"
#
#                                                  summary  unixReviewTime
# 0             Work Well - Should Have Bought Longer Ones      1313539200
# 1                                       Okay long cables      1315094400
# 2                             Looks and feels heavy Duty      1374710400
# 3                  Excellent choice for Jumper Cables!!!      1292889600
# 4                 Excellent, High Quality Starter Cables      1341360000
# 5                                   Compact and Strong !      1258156800
# 6                                            nice cables      1326153600
# 7                                   for cars and pickups      1371081600
# 8      Coleman Cable 08665 12-Feet Heavy-Duty Truck a...      1374105600
# 9                                                  Beefy      1390348800
# 10                                   fine consumer grade      1381708800
# 11                         Jumper Cables - The Real Deal      1287705600
# 12                                         Great quality      1388102400
# 13                        Not sure if they're really 2ga      1292976000
# 14                    Plated copper wire from what I see      1378598400
# 15              Only 4 stars because I haven't used them      1358380800
# 16                        Does what I expected it to do.      1384473600
# 17                 Extend-A-Truck 944 Truck Bed Extender      1283731200
# 18                       No Brainer, Easy to Use, Sturdy      1313020800
# 19                                          Easy install      1341792000
# 20                                              Love It!      1348531200
# 21                                            Great idea      1342396800
# 22        Good design and solid construction and compact      1327363200
# 23                           Perfect for my outside car!      1307232000
# 24                                               average      1241654400
# 25                           Does what it is supposed to      1248134400
# 26          GREAT FOR THOSE WHO TAKE PRIDE IN THEIR RIDE      1230854400
# 27                                  Gentle yet effective      1248307200
# 28                                           What to say      1400198400
# 29                                   The best car duster      1362528000
# ...                                                  ...             ...
# 20443                             Funky car lighting kit      1396224000
# 20444  Trick your ride! I love this kit! (Also works ...      1400025600
# 20445                         Bright but with some flaws      1397520000
# 20446                                interesting product      1400025600
# 20447          Simple plug in and go - anyone can do it!      1397952000
# 20448                                    Tricks Out Well      1396569600
# 20449  Super cool, super easy... installed these in m...      1395878400
# 20450      Turn you stove top into a giant cutting board      1405814400
# 20451      The work surface is nice size, and built well      1404777600
# 20452                           Wonderful kitchen asset!      1404259200
# 20453                              Beauty Meets Function      1405900800
# 20454        I love this for my home kitchen counter top      1405555200
# 20455  Additional counter space, but have to be a lit...      1403654400
# 20456               Stops the glare from sun or at night      1404691200
# 20457               Good for some people, not for others      1405123200
# 20458                                  Not Great for SUV      1404604800
# 20459                  Works well for some situations...      1404518400
# 20460     Does What it Promises but Size is a Limitation      1405468800
# 20461                                          Flipshade      1405209600
# 20462  works, but has limitations you may not want to...      1404345600
# 20463                                         Great Item      1373846400
# 20464                                stretchable tubular      1387152000
# 20465     wanna look cool then buy this you will love it      1384819200
# 20466                              It's ok fo the money?      1394841600
# 20467                                              ehhhh      1392076800
# 20468                    Excellent quality for the price      1396915200
# 20469  Light weight neck and face cover with whimsica...      1391472000
# 20470            I love to ride with my Skull Face Mask.      1386547200
# 20471                              Great neck protection      1357171200
# 20472                                          FACE MASK      1395100800
#
# [20473 rows x 9 columns]

# %% [markdown]
# b) downcase all the content

# %%
data1 = updateCol(data, 'reviewText', lambda text: text.lower())
print(data1['reviewText'])
# Out:
# 0        i needed a set of jumper cables for my new car...
# 1        these long cables work fine for my truck, but ...
# 2        can't comment much on these since they have no...
# 3        i absolutley love amazon!!!  for the price of ...
# 4        i purchased the 12' feet long cable set and th...
# 5        these jumper cables are heavy duty, yet easy t...
# 6        bought these for my k2500 suburban plenty of l...
# 7        these are good enough to get most motorized ve...
# 8        the coleman cable 08665 12-feet heavy-duty tru...
# 9        i have an old car, its bound to need these som...
# 10       i seem to use jumper cables at least several t...
# 11       all other jumper cables are not real jumper ca...
# 12       i'm one of those guys who stops and helps peop...
# 13       so these aren't the best cables you can buy.  ...
# 14       it is hard to find pure copper cabled jumper c...
# 15       these are an insurance policy for my land rove...
# 16       this product serves its purpose. i use it for ...
# 17       hitch extender is good for kayak transport and...
# 18
# 19       package arrived a bit ragged but it was all th...
# 20       this was exactly what i needed for transportin...
# 21       i bought these to haul my two kayaks.  works g...
# 22       i have owned trucks for many years and gotten ...
# 23       this is a must for anybody who wants to keep t...
# 24       this product does what it is supposed to do, b...
# 25       i would not buy this product again. it does wh...
# 26       i own the original california car duster and i...
# 27       like most car detail enthusiasts, i never like...
# 28       takes the dust off my car without leaving any ...
# 29       really the best car duster out there in my opi...
#                                ...
# 20443    great kit at a great price. usually if you go ...
# 20444    ah, this is such goofy fun, to jazz up your ca...
# 20445    basically these led lights are a nice addition...
# 20446    we've never had a product like this before, bu...
# 20447    ok, i'm a light nut. i fabricate my own led li...
# 20448    nice addition to the interior of any hot teens...
# 20449    while most will probably install these inside ...
# 20450    what an awesome idea this board is. it turns y...
# 20451    the work surface is nice size, and built well....
# 20452    i have a small kitchen, so using the stove top...
# 20453    if you've ever needed a little more work space...
# 20454    thin,light weightdurablebeautifulthis is a muc...
# 20455    wife 2.0 has never much cared for the kitchen ...
# 20456    i live in a very sunny climate.  at least once...
# 20457    this is an interesting product. it definitely ...
# 20458    this actually works pretty well. the yellow re...
# 20459    this is a vision visor for the car. it has two...
# 20460    i'm afraid i'm not sold on this. it does exact...
# 20461    it is a good sunshade for driving on bright su...
# 20462    i received a visor set free for review purpose...
# 20463    keeps the bugs out of your mouth while looking...
# 20464    i use them all the time when i ride or not i h...
# 20465    i think this is a cool yet sweet looking half ...
# 20466    i honestly don't think it's worth $3, but for ...
# 20467    very thin material. not very warm at all.. bar...
# 20468    i've bought 10 of these over the past year to ...
# 20469    ok, i have to admit, the price of this item di...
# 20470    i love my skull face mask. it makes me outstan...
# 20471    this mask of course as described is half-face ...
# 20472    good light weight for just cool nights or rain...
# Name: reviewText, Length: 20473, dtype: object

# %% [markdown]
# c) remove punctuation

# %%
data2 = updateCol(data1, 'reviewText', lambda text: text.replace('.', ''))
print(data2['reviewText'][0])
# Out:
# i needed a set of jumper cables for my new car and these had good reviews and were at a good price  they have been used a few times already and do what they are supposed to - no complaints therewhat i will say is that 12 feet really isn't an ideal length  sure, if you pull up front bumper to front bumper they are plenty long, but a lot of times you will be beside another car or can't get really close  because of this, i would recommend something a little longer than 12'great brand - get 16' version though

# %% [markdown]
# d) reduce words to stems (note: this computation takes some time...)
#
# Note: nltk.word_tokenize requires an extra package. If you get errors from below that urge you to download stuff, here are the steps:
#
# 1. import nltk
# 2. nltk.download()
# 3. choose "d" for "download"
# 4. type "punkt" and hit enter
# 5. great success!

# %%
import nltk
from nltk.stem.snowball import SnowballStemmer

stemmer = SnowballStemmer('english')

def stemSentence(sentence):
    return " ".join(list(map(stemmer.stem, nltk.word_tokenize(sentence))))

data3 = updateCol(data2, 'reviewText', lambda text: stemSentence(text))
print(data3)
# Out:
#              asin   helpful  overall  \
# 0      B00002243X    [4, 4]        5
# 1      B00002243X    [1, 1]        4
# 2      B00002243X    [0, 0]        5
# 3      B00002243X  [19, 19]        5
# 4      B00002243X    [0, 0]        5
# 5      B00002243X    [1, 1]        5
# 6      B00002243X    [1, 1]        5
# 7      B00002243X    [0, 0]        5
# 8      B00002243X    [0, 0]        4
# 9      B00002243X    [0, 0]        5
# 10     B00002243Z    [0, 0]        4
# 11     B00002243Z  [19, 21]        5
# 12     B00002243Z    [0, 0]        5
# 13     B00002243Z  [20, 21]        4
# 14     B00002243Z    [1, 1]        4
# 15     B00002243Z    [1, 3]        4
# 16     B00008BKX5    [0, 0]        3
# 17     B00008BKX5    [3, 4]        4
# 18     B00008BKX5  [51, 51]        5
# 19     B00008BKX5    [0, 0]        5
# 20     B00008BKX5    [0, 0]        5
# 21     B00008BKX5    [0, 0]        4
# 22     B00008BKX5    [1, 1]        5
# 23     B00008RW9U    [1, 2]        5
# 24     B00008RW9U    [3, 3]        3
# 25     B00008RW9U   [3, 10]        2
# 26     B00008RW9U    [0, 0]        5
# 27     B00008RW9U    [0, 0]        5
# 28     B00008RW9U    [0, 0]        5
# 29     B00008RW9U    [0, 0]        5
# ...           ...       ...      ...
# 20443  B00I93BOZ0    [1, 1]        5
# 20444  B00I93BOZ0    [0, 0]        5
# 20445  B00I93BOZ0    [0, 0]        3
# 20446  B00I93BOZ0    [0, 0]        4
# 20447  B00I93BOZ0    [0, 0]        5
# 20448  B00I93BOZ0    [0, 0]        5
# 20449  B00I93BOZ0    [1, 1]        5
# 20450  B00JGM7Z5Q    [0, 0]        5
# 20451  B00JGM7Z5Q    [1, 1]        5
# 20452  B00JGM7Z5Q    [1, 1]        5
# 20453  B00JGM7Z5Q    [0, 0]        5
# 20454  B00JGM7Z5Q    [0, 0]        5
# 20455  B00JGM7Z5Q    [4, 8]        4
# 20456  B00JGP8I1S    [2, 2]        5
# 20457  B00JGP8I1S    [0, 0]        3
# 20458  B00JGP8I1S    [2, 2]        4
# 20459  B00JGP8I1S    [2, 2]        5
# 20460  B00JGP8I1S    [1, 1]        3
# 20461  B00JGP8I1S    [2, 2]        4
# 20462  B00JGP8I1S    [1, 1]        3
# 20463  B00KIAQ8VW    [0, 0]        5
# 20464  B00KIAQ8VW    [0, 0]        4
# 20465  B00KIAQ8VW    [0, 0]        5
# 20466  B00KIAQ8VW    [0, 0]        3
# 20467  B00KIAQ8VW    [0, 0]        2
# 20468  B00KIAQ8VW    [1, 1]        5
# 20469  B00KIAQ8VW    [0, 0]        2
# 20470  B00KIAQ8VW    [0, 0]        5
# 20471  B00KIAQ8VW    [0, 0]        5
# 20472  B00KIAQ8VW    [0, 0]        5
#
#                                               reviewText   reviewTime  \
# 0      i need a set of jumper cabl for my new car and...  08 17, 2011
# 1      these long cabl work fine for my truck , but t...   09 4, 2011
# 2      ca n't comment much on these sinc they have no...  07 25, 2013
# 3      i absolutley love amazon ! ! ! for the price o...  12 21, 2010
# 4      i purchas the 12 ' feet long cabl set and they...   07 4, 2012
# 5      these jumper cabl are heavi duti , yet easi to...  11 14, 2009
# 6      bought these for my k2500 suburban plenti of l...  01 10, 2012
# 7      these are good enough to get most motor vehicl...  06 13, 2013
# 8      the coleman cabl 08665 12-feet heavy-duti truc...  07 18, 2013
# 9      i have an old car , it bound to need these som...  01 22, 2014
# 10     i seem to use jumper cabl at least sever time ...  10 14, 2013
# 11     all other jumper cabl are not real jumper cabl...  10 22, 2010
# 12     i 'm one of those guy who stop and help peopl ...  12 27, 2013
# 13     so these are n't the best cabl you can buy for...  12 22, 2010
# 14     it is hard to find pure copper cabl jumper cab...   09 8, 2013
# 15     these are an insur polici for my land rover an...  01 17, 2013
# 16     this product serv it purpos i use it for haul ...  11 15, 2013
# 17     hitch extend is good for kayak transport and a...   09 6, 2010
# 18                                                        08 11, 2011
# 19     packag arriv a bit rag but it was all there , ...   07 9, 2012
# 20     this was exact what i need for transport my fi...  09 25, 2012
# 21     i bought these to haul my two kayak work great...  07 16, 2012
# 22     i have own truck for mani year and gotten by w...  01 24, 2012
# 23     this is a must for anybodi who want to keep th...   06 5, 2011
# 24     this product doe what it is suppos to do , but...   05 7, 2009
# 25     i would not buy this product again it doe what...  07 21, 2009
# 26     i own the origin california car duster and it ...   01 2, 2009
# 27     like most car detail enthusiast , i never like...  07 23, 2009
# 28     take the dust off my car without leav ani stre...  05 16, 2014
# 29     realli the best car duster out there in my opi...   03 6, 2013
# ...                                                  ...          ...
# 20443  great kit at a great price usual if you go for...  03 31, 2014
# 20444  ah , this is such goofi fun , to jazz up your ...  05 14, 2014
# 20445  basic these led light are a nice addit to unde...  04 15, 2014
# 20446  we ve never had a product like this befor , bu...  05 14, 2014
# 20447  ok , i 'm a light nut i fabric my own led ligh...  04 20, 2014
# 20448  nice addit to the interior of ani hot teen car...   04 4, 2014
# 20449  while most will probabl instal these insid the...  03 27, 2014
# 20450  what an awesom idea this board is it turn your...  07 20, 2014
# 20451  the work surfac is nice size , and built well ...   07 8, 2014
# 20452  i have a small kitchen , so use the stove top ...   07 2, 2014
# 20453  if you ve ever need a littl more work space in...  07 21, 2014
# 20454  thin , light weightdurablebeautifulthi is a mu...  07 17, 2014
# 20455  wife 20 has never much care for the kitchen in...  06 25, 2014
# 20456  i live in a veri sunni climat at least onc per...   07 7, 2014
# 20457  this is an interest product it definit has it ...  07 12, 2014
# 20458  this actual work pretti well the yellow realli...   07 6, 2014
# 20459  this is a vision visor for the car it has two ...   07 5, 2014
# 20460  i 'm afraid i 'm not sold on this it doe exact...  07 16, 2014
# 20461  it is a good sunshad for drive on bright sun i...  07 13, 2014
# 20462  i receiv a visor set free for review purpos , ...   07 3, 2014
# 20463  keep the bug out of your mouth while look bada...  07 15, 2013
# 20464  i use them all the time when i ride or not i h...  12 16, 2013
# 20465  i think this is a cool yet sweet look half sku...  11 19, 2013
# 20466  i honest do n't think it 's worth $ 3 , but fo...  03 15, 2014
# 20467  veri thin materi not veri warm at all barley b...  02 11, 2014
# 20468  i ve bought 10 of these over the past year to ...   04 8, 2014
# 20469  ok , i have to admit , the price of this item ...   02 4, 2014
# 20470  i love my skull face mask it make me outstand ...   12 9, 2013
# 20471  this mask of cours as describ is half-fac but ...   01 3, 2013
# 20472  good light weight for just cool night or rain ...  03 18, 2014
#
#            reviewerID                                      reviewerName  \
# 0      A3F73SC1LY51OO                                   Alan Montgomery
# 1      A20S66SKYXULG2                                          alphonse
# 2      A2I8LFSN2IS5EO                                             Chris
# 3      A3GT2EWQSO45ZG                                            DeusEx
# 4      A3ESWJPAVRPWB4                                      E. Hernandez
# 5       A1ORODEBRN64C                      James F. Magowan "Jimmy Mac"
# 6      A2R49ZN3G6FTCQ                                   John M. Harrell
# 7      A1Q65KYDKXIX8E                                        Leeland H.
# 8      A3BI8BKIHESDNQ                                  L. J. Cunningham
# 9      A1R089P5AS26UE                                              Mike
# 10     A2TQST4IPVA0EC                                              ACAR
# 11     A3MQAQT8C6D1I7                                   AverageReviewer
# 12     A1C6RZG7XQZBUZ  C. Beard "I have not gone where I intended to...
# 13     A3GT2EWQSO45ZG                                            DeusEx
# 14     A3I23XW4L5ITOG                                           Hemmi06
# 15     A30ASPRK2VP8QC                                             Robin
# 16     A1KKOA3FP2DMBW                                    Brian LaFrance
# 17     A3L1VJMHFWONCB                                CDP "Double00Buck"
# 18      A1HPC4BDRLR60                                        Delta Echo
# 19     A3IHX99Z9OK2Y9                                         Gulfcoast
# 20      AT5F1MKA8C2IZ                                         R. Gillis
# 21      A4YV49T8Y0X94                                   RobbyB "RobbyB"
# 22     A204K1OFE8OB9Y                                            Winter
# 23     A36HBGDEFPWD0U                                             Brett
# 24     A2FJKITDY5UUHJ                                  Charles M. Cline
# 25     A3LYC4BXRDE5RZ                                       Chi Car Guy
# 26      AEL6CQNQXONBX                                    Cute Chihuahua
# 27     A3APEIJOQXE142                     Daniel Attila "Daniel Attila"
# 28     A24EQC4LXYPT4E                                              Dave
# 29     A2H5KD2A9MUZEX                                           Gaazmon
# ...               ...                                               ...
# 20443  A2JMJVNTBL7K7E                               K. Lin "yesuaini99"
# 20444   ASFW4ZMNZJKDA                                           Mainiac
# 20445  A2X6J6AFLLYVXH                                    Michael Hilton
# 20446  A105S56ODHGJEK                Peace Daddy "Eclectic ReflectionZ"
# 20447  A3LGT6UZL99IW1  Richard C. Drew "Anaal Nathra/Uthe vas Bethod...
# 20448  A3MQ15651KGVLJ                                   Rick L. Parrish
# 20449   AM9APPMIE1BHZ                                      Sparky Jones
# 20450  A1F7YU6O5RU432                                    Angela Streiff
# 20451  A397CWU6DM3O5G                                             ganka
# 20452  A1M1Y5UGONAW06                                              Jody
# 20453  A3SD3E6FIS6CS9                                Marine Corps Nomad
# 20454  A376OJHLE6SU9Q                                           M. Wolf
# 20455  A25QJBK33C4O0R                               terpfan1980 "Barry"
# 20456  A19UTUEBWKIZFT                                               AKN
# 20457  A1T1YSCDW0PD25                                        A. Wiersch
# 20458  A34BZM6S9L7QI4                       Candy Cane "Is it just me?"
# 20459   AYB4ELCS5AM8P                               John B. Goode "JBG"
# 20460  A1EVV74UQYVKRY                                           K. Groh
# 20461  A1ODOGXEYECQQ8                                            Nuknuk
# 20462  A3A4ZAIBQWKOZS                                  Stephen M. Lerch
# 20463  A1RH7WA3YFDQ5H                                        Denise2012
# 20464  A1PMV0WV45OPEE                                         Dwayne C.
# 20465   ACHBPQUWQZMSL                              ernies point of veiw
# 20466  A1TEBSNK5A9XX9                                               JUL
# 20467  A212UJA6XIOTUT                                               kaz
# 20468  A1KB43BI085A48                                           Mike F.
# 20469  A3HIUWKL4D853W                                              RayH
# 20470  A1S95WASXJ02VX                               Roberto Aguilar Jr.
# 20471  A2IID0Z6EHF5KP                                            Soarer
# 20472  A3HKZTFCPIK2OE                SSG Barnes (ABN) "James C. Barnes"
#
#                                                  summary  unixReviewTime
# 0             Work Well - Should Have Bought Longer Ones      1313539200
# 1                                       Okay long cables      1315094400
# 2                             Looks and feels heavy Duty      1374710400
# 3                  Excellent choice for Jumper Cables!!!      1292889600
# 4                 Excellent, High Quality Starter Cables      1341360000
# 5                                   Compact and Strong !      1258156800
# 6                                            nice cables      1326153600
# 7                                   for cars and pickups      1371081600
# 8      Coleman Cable 08665 12-Feet Heavy-Duty Truck a...      1374105600
# 9                                                  Beefy      1390348800
# 10                                   fine consumer grade      1381708800
# 11                         Jumper Cables - The Real Deal      1287705600
# 12                                         Great quality      1388102400
# 13                        Not sure if they're really 2ga      1292976000
# 14                    Plated copper wire from what I see      1378598400
# 15              Only 4 stars because I haven't used them      1358380800
# 16                        Does what I expected it to do.      1384473600
# 17                 Extend-A-Truck 944 Truck Bed Extender      1283731200
# 18                       No Brainer, Easy to Use, Sturdy      1313020800
# 19                                          Easy install      1341792000
# 20                                              Love It!      1348531200
# 21                                            Great idea      1342396800
# 22        Good design and solid construction and compact      1327363200
# 23                           Perfect for my outside car!      1307232000
# 24                                               average      1241654400
# 25                           Does what it is supposed to      1248134400
# 26          GREAT FOR THOSE WHO TAKE PRIDE IN THEIR RIDE      1230854400
# 27                                  Gentle yet effective      1248307200
# 28                                           What to say      1400198400
# 29                                   The best car duster      1362528000
# ...                                                  ...             ...
# 20443                             Funky car lighting kit      1396224000
# 20444  Trick your ride! I love this kit! (Also works ...      1400025600
# 20445                         Bright but with some flaws      1397520000
# 20446                                interesting product      1400025600
# 20447          Simple plug in and go - anyone can do it!      1397952000
# 20448                                    Tricks Out Well      1396569600
# 20449  Super cool, super easy... installed these in m...      1395878400
# 20450      Turn you stove top into a giant cutting board      1405814400
# 20451      The work surface is nice size, and built well      1404777600
# 20452                           Wonderful kitchen asset!      1404259200
# 20453                              Beauty Meets Function      1405900800
# 20454        I love this for my home kitchen counter top      1405555200
# 20455  Additional counter space, but have to be a lit...      1403654400
# 20456               Stops the glare from sun or at night      1404691200
# 20457               Good for some people, not for others      1405123200
# 20458                                  Not Great for SUV      1404604800
# 20459                  Works well for some situations...      1404518400
# 20460     Does What it Promises but Size is a Limitation      1405468800
# 20461                                          Flipshade      1405209600
# 20462  works, but has limitations you may not want to...      1404345600
# 20463                                         Great Item      1373846400
# 20464                                stretchable tubular      1387152000
# 20465     wanna look cool then buy this you will love it      1384819200
# 20466                              It's ok fo the money?      1394841600
# 20467                                              ehhhh      1392076800
# 20468                    Excellent quality for the price      1396915200
# 20469  Light weight neck and face cover with whimsica...      1391472000
# 20470            I love to ride with my Skull Face Mask.      1386547200
# 20471                              Great neck protection      1357171200
# 20472                                          FACE MASK      1395100800
#
# [20473 rows x 9 columns]

# %% [markdown]
# d) filtering and saving the data

# %%
positiveReviews = data3[data3['overall'] > 3]
negativeReviews = data3[data3['overall'] < 3]

def write_reviews_to_file(filename, reviewSeries):
    file = open(filename, 'w')
    for index, value in reviewSeries.iteritems():
        file.write(value)
        file.write("\n")
    file.close()

write_reviews_to_file('ex2_positive_reviews.txt', positiveReviews['reviewText'])
write_reviews_to_file('ex2_negative_reviews.txt', negativeReviews['reviewText'])
